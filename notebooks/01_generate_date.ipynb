# %%
import sys 
sys.path.insert(0, "../")

# %%
from hr_data_generation import hr_gen, config
import yaml

employee_data_path = config.EMPLOYEE_DATA_PATH

with open(employee_data_path, "r") as f: 
    employee_data = yaml.load(f, Loader=yaml.SafeLoader)

# %%
employees = hr_gen.generate_employees(10, employee_data)

# %%
employees
# Out:
# {1: {'age': 32,
#   'gender': 'male',
#   'first_name': 'Quentin',
#   'last_name': 'Cruz',
#   'hiring_date': datetime.date(2019, 4, 16)},
#  2: {'age': 46,
#   'gender': 'female',
#   'first_name': 'Caroline',
#   'last_name': 'Hamilton',
#   'hiring_date': datetime.date(2011, 4, 4)},
#  3: {'age': 29,
#   'gender': 'female',
#   'first_name': 'Nisha',
#   'last_name': 'Castro',
#   'hiring_date': datetime.date(2021, 5, 18)},
#  4: {'age': 44,
#   'gender': 'male',
#   'first_name': 'Elliot',
#   'last_name': 'Wagner',
#   'hiring_date': datetime.date(2010, 2, 2)},
#  5: {'age': 57,
#   'gender': 'male',
#   'first_name': 'Beckett',
#   'last_name': 'Burns',
#   'hiring_date': datetime.date(2021, 9, 17)},
#  6: {'age': 42,
#   'gender': 'female',
#   'first_name': 'Monica',
#   'last_name': 'Medina',
#   'hiring_date': datetime.date(2008, 5, 11)},
#  7: {'age': 55,
#   'gender': 'male',
#   'first_name': 'Sean',
#   'last_name': 'Bell',
#   'hiring_date': datetime.date(1993, 12, 7)},
#  8: {'age': 25,
#   'gender': 'na',
#   'first_name': 'Robin',
#   'last_name': 'Boyd',
#   'hiring_date': datetime.date(2022, 6, 16)},
#  9: {'age': 44,
#   'gender': 'male',
#   'first_name': 'Kieran',
#   'last_name': 'Wright',
#   'hiring_date': datetime.date(2007, 6, 20)},
#  10: {'age': 37,
#   'gender': 'male',
#   'first_name': 'Angus',
#   'last_name': 'Washington',
#   'hiring_date': datetime.date(2012, 1, 6)}}
